# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# # Observations
# ## Observation 1
#     While the equator shows a clear peak in heat at latitude zero, there are more spikes in temperatures just below the equator.
#
# ## Obersvation 2
#     Humidity drops just north of the equator which may suggest some kind of significant properties in climate.
#
# ## Obersvation 3
#     Wind speeds increase at a small rate the further north you measure it.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %%
type(cities)
# Out:
# list

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities
# Out:
# ['ilulissat',
#  'ushuaia',
#  'rikitea',
#  'jasper',
#  'saldanha',
#  'taolanaro',
#  'upernavik',
#  'mataura',
#  'ahipara',
#  'loreto',
#  'saint george',
#  'labutta',
#  'cayenne',
#  'arraial do cabo',
#  'vaini',
#  'port alfred',
#  'cariati',
#  'terrace',
#  'severnyy',
#  'attawapiskat',
#  'maine-soroa',
#  'kapaa',
#  'bethel',
#  'paoua',
#  'bukama',
#  'ixtapa',
#  'barrow',
#  'arona',
#  'klyuchi',
#  'camabatela',
#  'taperoa',
#  'edinburg',
#  'hobart',
#  'amderma',
#  'pevek',
#  'barentsburg',
#  'nichinan',
#  'olafsvik',
#  'puerto ayora',
#  'torbay',
#  'beringovskiy',
#  'samusu',
#  'buchanan',
#  'castro',
#  'busselton',
#  'norman wells',
#  'nikolskoye',
#  'coquimbo',
#  'batagay',
#  'mareeba',
#  'new norfolk',
#  'hermanus',
#  'necochea',
#  'albany',
#  'sobolevo',
#  'natal',
#  'beisfjord',
#  'byron bay',
#  'sisimiut',
#  'tarrafal',
#  'taltal',
#  'gornopravdinsk',
#  'kongolo',
#  'hilo',
#  'bosaso',
#  'sitka',
#  'vrangel',
#  'victoria',
#  'chuy',
#  'cape town',
#  'tsihombe',
#  'karkaralinsk',
#  'port macquarie',
#  'liverpool',
#  'bay saint louis',
#  'san ignacio',
#  'severo-kurilsk',
#  'vila franca do campo',
#  'aklavik',
#  'georgetown',
#  'san juan de colon',
#  'nanortalik',
#  'waipawa',
#  'talcahuano',
#  'carballo',
#  'khatanga',
#  'atuona',
#  'illoqqortoormiut',
#  'lawrenceburg',
#  'vardo',
#  'hofn',
#  'nuuk',
#  'salihorsk',
#  'lazi',
#  'saint-philippe',
#  'mys shmidta',
#  'tommot',
#  'dikson',
#  'deputatskiy',
#  'bunbury',
#  'floro',
#  'thompson',
#  'lebu',
#  'valencia',
#  'mao',
#  'ribeira grande',
#  'avarua',
#  'east london',
#  'pisco',
#  'price',
#  'chokurdakh',
#  'bamenda',
#  'ipixuna',
#  'mudanjiang',
#  'carnarvon',
#  'bluff',
#  'inhambane',
#  'coos bay',
#  'kiruna',
#  'nome',
#  'codrington',
#  'yellowknife',
#  'bredasdorp',
#  'sungaipenuh',
#  'shingu',
#  'saskylakh',
#  'nizhnevartovsk',
#  'san patricio',
#  'coihaique',
#  'lida',
#  'avera',
#  'buala',
#  'kropotkin',
#  'namibe',
#  'belushya guba',
#  'mackay',
#  'barsovo',
#  'kapit',
#  'la sarre',
#  'salalah',
#  'faanui',
#  'airai',
#  'punta arenas',
#  'shahreza',
#  'cascais',
#  'wilmington',
#  'tabiauea',
#  'macusani',
#  'america dourada',
#  'westport',
#  'pangnirtung',
#  'tasiilaq',
#  'kaitangata',
#  'pacific grove',
#  'mitu',
#  'yar-sale',
#  'pangody',
#  'lompoc',
#  'sarh',
#  'bombay',
#  'jalu',
#  'los llanos de aridane',
#  'husavik',
#  'sabang',
#  'northam',
#  'alofi',
#  'meyungs',
#  'moree',
#  'port hardy',
#  'vaitupu',
#  'esperance',
#  'flinders',
#  'dingli',
#  'saint anthony',
#  'slave lake',
#  'ugoofaaru',
#  'urbano santos',
#  'qaanaaq',
#  'svetlaya',
#  'mar del plata',
#  'cherskiy',
#  'xuddur',
#  'nador',
#  'arman',
#  'fort nelson',
#  'abu kamal',
#  'dalbandin',
#  'tromso',
#  'belaya gora',
#  'neiafu',
#  'drumheller',
#  'provideniya',
#  'tuatapere',
#  'mancio lima',
#  'tulsipur',
#  'sumbawa',
#  'grand river south east',
#  'mercedes',
#  'macaboboni',
#  'bagdarin',
#  'solnechnyy',
#  'ulladulla',
#  'khovu-aksy',
#  'tanshui',
#  'tula',
#  'poum',
#  'butaritari',
#  'mana',
#  'palmer',
#  'saleaula',
#  'acapulco',
#  'morros',
#  'wahran',
#  'talnakh',
#  'nantucket',
#  'mitzic',
#  'tabory',
#  'hovd',
#  'bambous virieux',
#  'pasighat',
#  'tyler',
#  'the valley',
#  'scottsbluff',
#  'dingle',
#  'ye',
#  'kulhudhuffushi',
#  'pochutla',
#  'inirida',
#  'olinda',
#  'panaba',
#  'tarudant',
#  'general roca',
#  'thinadhoo',
#  'sao filipe',
#  'touros',
#  'selma',
#  'gangotri',
#  'blagoyevo',
#  'sentyabrskiy',
#  'hamilton',
#  'faya',
#  'khonuu',
#  'pamekasan',
#  'portland',
#  'dimapur',
#  'bucerias',
#  'bianzhuang',
#  'kodiak',
#  'cidreira',
#  'turukhansk',
#  'tilichiki',
#  'cururupu',
#  'nouadhibou',
#  'kloulklubed',
#  'dunedin',
#  'kargasok',
#  'tuktoyaktuk',
#  'tselinnoye',
#  'chacabuco',
#  'kieta',
#  'palabuhanratu',
#  'tiznit',
#  'chervona sloboda',
#  'hailar',
#  'chimbote',
#  'kruisfontein',
#  'corn island',
#  'lagoa',
#  'ponta delgada',
#  'sumoto',
#  'pucallpa',
#  'zastavna',
#  'nara',
#  'san-pedro',
#  'butler',
#  'mahebourg',
#  'jumla',
#  'klaksvik',
#  'narsaq',
#  'tateyama',
#  'sur',
#  'ponta do sol',
#  'roald',
#  'sola',
#  'taoudenni',
#  'san policarpo',
#  'hualmay',
#  'spantov',
#  'pointe-noire',
#  'bolungarvik',
#  'kahului',
#  'bontang',
#  'nabire',
#  'bavleny',
#  'jiangyou',
#  'brae',
#  'neryungri',
#  'ishigaki',
#  'lazarev',
#  'partizanskoye',
#  'uribia',
#  'jamestown',
#  'trofors',
#  'katobu',
#  'kununurra',
#  'chon daen',
#  'vao',
#  'corinth',
#  'constitucion',
#  'kendari',
#  'mataram',
#  'burica',
#  'hervey bay',
#  'lavrentiya',
#  'paracuru',
#  'kodinsk',
#  'santa cruz de tenerife',
#  'breves',
#  'kathmandu',
#  'aliquippa',
#  'hithadhoo',
#  'maua',
#  'teguise',
#  'tuy hoa',
#  'san antonio',
#  'papasquiaro',
#  'caravelas',
#  'makakilo city',
#  'karaul',
#  'hasaki',
#  'salinopolis',
#  'fomboni',
#  'clyde river',
#  'baherden',
#  'ilhabela',
#  'coalinga',
#  'rabo de peixe',
#  'luderitz',
#  'puerto carreno',
#  'tsaratanana',
#  'festus',
#  'mbuji-mayi',
#  'puri',
#  'pushchino',
#  'griffith',
#  'san quintin',
#  'kassala',
#  'nchelenge',
#  'lensk',
#  'nizhneye kazanishche',
#  'komsomolskiy',
#  'tevaitoa',
#  'ambatofinandrahana',
#  'kavieng',
#  'mitsamiouli',
#  'lazaro cardenas',
#  'bilibino',
#  'port elizabeth',
#  'fortuna',
#  'sibu',
#  'eyl',
#  'san cristobal',
#  'bambanglipuro',
#  'praia da vitoria',
#  'ust-koksa',
#  'kondopoga',
#  'dubbo',
#  'colares',
#  'lasa',
#  'petropavlovsk-kamchatskiy',
#  'beloha',
#  'viiratsi',
#  'sahrak',
#  'timmins',
#  'dandong',
#  'osmena',
#  'giovinazzo',
#  'rio grande',
#  'padang',
#  'primore',
#  'vestmannaeyjar',
#  'san andres',
#  'katsuura',
#  'ostrovnoy',
#  'bushehr',
#  'napier',
#  'cap malheureux',
#  'bandiagara',
#  'kumluca',
#  'mount isa',
#  'adrar',
#  'sao joao da barra',
#  'sao jose de ribamar',
#  'barbar',
#  'yarmouth',
#  'cheuskiny',
#  'birao',
#  'poopo',
#  'cangzhou',
#  'betsiamites',
#  'longyearbyen',
#  'ewa beach',
#  'myski',
#  'lourdes',
#  'fare',
#  'zhigansk',
#  'stornoway',
#  'grand gaube',
#  'dubai',
#  'guerrero negro',
#  'batagay-alyta',
#  'oromocto',
#  'yulara',
#  'chicama',
#  'kapuskasing',
#  'conceicao do araguaia',
#  'batsfjord',
#  'greenwood',
#  'kupang',
#  'freire',
#  'havoysund',
#  'mustvee',
#  'marang',
#  'vostok',
#  'xinan',
#  'samarai',
#  'temirtau',
#  'lata',
#  'shache',
#  'naze',
#  'kibala',
#  'port blair',
#  'acton',
#  'acarau',
#  'arlit',
#  'mersing',
#  'itirapina',
#  'feldbach',
#  'bougouni',
#  'orchard homes',
#  'suntar',
#  'saint-denis',
#  'assiniboia',
#  'filadelfia',
#  'launceston',
#  'dingzhou',
#  'nizhneyansk',
#  'wittmund',
#  'marsh harbour',
#  'xilagani',
#  'ust-tsilma',
#  'kismayo',
#  'asau',
#  'srednekolymsk',
#  'shahr-e kord',
#  'paramonga',
#  'aketi',
#  'shido',
#  'kjopsvik',
#  'lazurne',
#  'mumford',
#  'andreyevo',
#  'monrovia',
#  'beohari',
#  'rio cuarto',
#  'povenets',
#  'zhezkazgan',
#  'kamenskoye',
#  'nyurba',
#  'mossendjo',
#  'iqaluit',
#  'tessalit',
#  'cabo san lucas',
#  'oistins',
#  'cafarnaum',
#  'nelson bay',
#  'virginia beach',
#  'terenos',
#  'tazmalt',
#  'plettenberg bay',
#  'guhagar',
#  'filingue',
#  'honningsvag',
#  'bandar-e lengeh',
#  'junin',
#  'yumen',
#  'araouane',
#  'mentok',
#  'hobyo',
#  'ridgetown',
#  'dehloran',
#  'powell river',
#  'bonavista',
#  'matay',
#  'caronport',
#  'qaqortoq',
#  'grindavik',
#  'kailua',
#  'alice springs',
#  'rio gallegos',
#  'isangel',
#  'prieska',
#  'champua',
#  'ballina',
#  'nishihara',
#  'san miguel',
#  'kawalu',
#  'fairlie',
#  'koungheul',
#  'okhotsk',
#  'katangi',
#  'kholm',
#  'dyatkovo',
#  'anadyr',
#  'talaya',
#  'sesimbra',
#  'oros',
#  'verkhoyansk',
#  'katangli',
#  'san juan',
#  'kjollefjord',
#  'road town',
#  'mishan',
#  'laguna',
#  'lanxi',
#  'sarlat-la-caneda',
#  'carutapera',
#  'cockburn town',
#  'harper',
#  'sanary-sur-mer',
#  'tiksi',
#  'fazilka',
#  'wajima',
#  'lewisporte',
#  'dhidhdhoo',
#  'zhigalovo',
#  'gambela',
#  'lorengau',
#  'draguseni',
#  'betim',
#  'araioses',
#  'bengkulu',
#  'bubaque',
#  'muros',
#  'riyadh',
#  'ambodifototra',
#  'dwarka',
#  'halalo',
#  'myitkyina',
#  'rosetta',
#  'camacha',
#  'magugu',
#  'ustyuzhna',
#  'itaituba',
#  'manadhoo',
#  'malacky',
#  'divnogorsk',
#  'sembe',
#  'skalistyy',
#  'semenivka',
#  'mugumu',
#  'tura',
#  'hambantota',
#  'roebourne',
#  'champerico',
#  'diffa',
#  'druzhba',
#  'zmiyiv',
#  'gawler',
#  'maniitsoq',
#  'kumo',
#  'sataua',
#  'hay river',
#  'conde',
#  'saint-francois',
#  'ruatoria',
#  'den helder',
#  'krivopolyanye',
#  'yirol',
#  'pindi gheb',
#  'buraydah',
#  'tagab',
#  'port-gentil',
#  'whitehorse',
#  'cordeiro',
#  'huarmey',
#  'geraldton',
#  'majene',
#  'aktash',
#  'lolua',
#  'monteagudo',
#  'ancud',
#  'vila velha',
#  'inongo',
#  'miraflores',
#  'enshi',
#  'proletarsk',
#  'tsiroanomandidy',
#  'erenhot',
#  'shimoda',
#  'bongor',
#  'novoagansk',
#  'jiwani',
#  'urumqi',
#  'show low',
#  'kenai',
#  'poso',
#  'wisconsin rapids',
#  'manono',
#  'marsa matruh',
#  'haines junction',
#  'little rock',
#  'marzuq',
#  'gorom-gorom',
#  'spencer']

# %%
# Set base url using API standards.
url = 'http://api.openweathermap.org/data/2.5/weather?'

# Start empty list to hold all iterated data.
all_data = []

# Set key:value sets to use as params with requests.get() function.
payload = {
'appid': weather_api_key,
'q': ''
}     

# Iterate over randomized list cities with index 'idx' and element 'city'
for idx, city in enumerate(cities):
    # Set dict bucket to hold key:value results for each iteration of 'city'
    current_data = {}
    
    # Pass city_name into query dict payload (params)
    payload['q'] = city
    
    # Set response bucket to hold request.get() function which references iterating params
    r = requests.get(url, payload)
    
    # Print url for checking
    print(r.url)
    
    # Print idx followed by payload iterate for humans.
    print(f"Processing City #{idx} {payload['q']}")
    
    # Convert readable from text to json, from json to df
    r_json = r.json()
    
    # Run try function and except keyerrors and index errors to catch any issues in API lookup
    try:
        current_data['City'] = r_json['name']
        current_data['Cloudiness'] = r_json['clouds']['all']
        current_data['Country'] = r_json['sys']['country']
        current_data['Date'] = r_json['dt']
        current_data['Humidity'] = r_json['main']['humidity']
        current_data['Lat'] = r_json['coord']['lat']
        current_data['Lng'] = r_json['coord']['lon']
        current_data['Max Temp'] = r_json['main']['temp_max']
        current_data['Wind Speed'] = r_json['wind']['speed']
        
        # Append dict 'current_data' to list 'all_data' each iteration.
        all_data.append(current_data)
        
    # If exception is found, no data is recorded and exception prints
    except (KeyError, IndexError):
          print("Missing field/result... skipping.")
    
    # Make pretty iteration break for humans.
    print("------------")
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ilulissat
# Processing City #0 ilulissat
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ushuaia
# Processing City #1 ushuaia
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=rikitea
# Processing City #2 rikitea
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=jasper
# Processing City #3 jasper
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=saldanha
# Processing City #4 saldanha
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=taolanaro
# Processing City #5 taolanaro
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=upernavik
# Processing City #6 upernavik
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mataura
# Processing City #7 mataura
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ahipara
# Processing City #8 ahipara
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=loreto
# Processing City #9 loreto
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=saint+george
# Processing City #10 saint george
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=labutta
# Processing City #11 labutta
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=cayenne
# Processing City #12 cayenne
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=arraial+do+cabo
# Processing City #13 arraial do cabo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=vaini
# Processing City #14 vaini
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=port+alfred
# Processing City #15 port alfred
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=cariati
# Processing City #16 cariati
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=terrace
# Processing City #17 terrace
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=severnyy
# Processing City #18 severnyy
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=attawapiskat
# Processing City #19 attawapiskat
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=maine-soroa
# Processing City #20 maine-soroa
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kapaa
# Processing City #21 kapaa
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bethel
# Processing City #22 bethel
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=paoua
# Processing City #23 paoua
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bukama
# Processing City #24 bukama
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ixtapa
# Processing City #25 ixtapa
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=barrow
# Processing City #26 barrow
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=arona
# Processing City #27 arona
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=klyuchi
# Processing City #28 klyuchi
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=camabatela
# Processing City #29 camabatela
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=taperoa
# Processing City #30 taperoa
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=edinburg
# Processing City #31 edinburg
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=hobart
# Processing City #32 hobart
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=amderma
# Processing City #33 amderma
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=pevek
# Processing City #34 pevek
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=barentsburg
# Processing City #35 barentsburg
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=nichinan
# Processing City #36 nichinan
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=olafsvik
# Processing City #37 olafsvik
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=puerto+ayora
# Processing City #38 puerto ayora
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=torbay
# Processing City #39 torbay
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=beringovskiy
# Processing City #40 beringovskiy
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=samusu
# Processing City #41 samusu
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=buchanan
# Processing City #42 buchanan
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=castro
# Processing City #43 castro
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=busselton
# Processing City #44 busselton
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=norman+wells
# Processing City #45 norman wells
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=nikolskoye
# Processing City #46 nikolskoye
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=coquimbo
# Processing City #47 coquimbo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=batagay
# Processing City #48 batagay
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mareeba
# Processing City #49 mareeba
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=new+norfolk
# Processing City #50 new norfolk
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=hermanus
# Processing City #51 hermanus
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=necochea
# Processing City #52 necochea
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=albany
# Processing City #53 albany
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sobolevo
# Processing City #54 sobolevo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=natal
# Processing City #55 natal
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=beisfjord
# Processing City #56 beisfjord
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=byron+bay
# Processing City #57 byron bay
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sisimiut
# Processing City #58 sisimiut
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tarrafal
# Processing City #59 tarrafal
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=taltal
# Processing City #60 taltal
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=gornopravdinsk
# Processing City #61 gornopravdinsk
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kongolo
# Processing City #62 kongolo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=hilo
# Processing City #63 hilo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bosaso
# Processing City #64 bosaso
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sitka
# Processing City #65 sitka
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=vrangel
# Processing City #66 vrangel
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=victoria
# Processing City #67 victoria
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=chuy
# Processing City #68 chuy
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=cape+town
# Processing City #69 cape town
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tsihombe
# Processing City #70 tsihombe
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=karkaralinsk
# Processing City #71 karkaralinsk
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=port+macquarie
# Processing City #72 port macquarie
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=liverpool
# Processing City #73 liverpool
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bay+saint+louis
# Processing City #74 bay saint louis
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=san+ignacio
# Processing City #75 san ignacio
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=severo-kurilsk
# Processing City #76 severo-kurilsk
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=vila+franca+do+campo
# Processing City #77 vila franca do campo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=aklavik
# Processing City #78 aklavik
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=georgetown
# Processing City #79 georgetown
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=san+juan+de+colon
# Processing City #80 san juan de colon
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=nanortalik
# Processing City #81 nanortalik
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=waipawa
# Processing City #82 waipawa
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=talcahuano
# Processing City #83 talcahuano
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=carballo
# Processing City #84 carballo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=khatanga
# Processing City #85 khatanga
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=atuona
# Processing City #86 atuona
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=illoqqortoormiut
# Processing City #87 illoqqortoormiut
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=lawrenceburg
# Processing City #88 lawrenceburg
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=vardo
# Processing City #89 vardo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=hofn
# Processing City #90 hofn
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=nuuk
# Processing City #91 nuuk
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=salihorsk
# Processing City #92 salihorsk
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=lazi
# Processing City #93 lazi
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=saint-philippe
# Processing City #94 saint-philippe
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mys+shmidta
# Processing City #95 mys shmidta
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tommot
# Processing City #96 tommot
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=dikson
# Processing City #97 dikson
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=deputatskiy
# Processing City #98 deputatskiy
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bunbury
# Processing City #99 bunbury
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=floro
# Processing City #100 floro
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=thompson
# Processing City #101 thompson
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=lebu
# Processing City #102 lebu
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=valencia
# Processing City #103 valencia
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mao
# Processing City #104 mao
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ribeira+grande
# Processing City #105 ribeira grande
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=avarua
# Processing City #106 avarua
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=east+london
# Processing City #107 east london
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=pisco
# Processing City #108 pisco
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=price
# Processing City #109 price
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=chokurdakh
# Processing City #110 chokurdakh
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bamenda
# Processing City #111 bamenda
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ipixuna
# Processing City #112 ipixuna
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mudanjiang
# Processing City #113 mudanjiang
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=carnarvon
# Processing City #114 carnarvon
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bluff
# Processing City #115 bluff
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=inhambane
# Processing City #116 inhambane
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=coos+bay
# Processing City #117 coos bay
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kiruna
# Processing City #118 kiruna
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=nome
# Processing City #119 nome
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=codrington
# Processing City #120 codrington
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=yellowknife
# Processing City #121 yellowknife
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bredasdorp
# Processing City #122 bredasdorp
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sungaipenuh
# Processing City #123 sungaipenuh
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=shingu
# Processing City #124 shingu
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=saskylakh
# Processing City #125 saskylakh
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=nizhnevartovsk
# Processing City #126 nizhnevartovsk
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=san+patricio
# Processing City #127 san patricio
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=coihaique
# Processing City #128 coihaique
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=lida
# Processing City #129 lida
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=avera
# Processing City #130 avera
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=buala
# Processing City #131 buala
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kropotkin
# Processing City #132 kropotkin
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=namibe
# Processing City #133 namibe
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=belushya+guba
# Processing City #134 belushya guba
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mackay
# Processing City #135 mackay
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=barsovo
# Processing City #136 barsovo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kapit
# Processing City #137 kapit
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=la+sarre
# Processing City #138 la sarre
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=salalah
# Processing City #139 salalah
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=faanui
# Processing City #140 faanui
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=airai
# Processing City #141 airai
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=punta+arenas
# Processing City #142 punta arenas
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=shahreza
# Processing City #143 shahreza
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=cascais
# Processing City #144 cascais
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=wilmington
# Processing City #145 wilmington
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tabiauea
# Processing City #146 tabiauea
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=macusani
# Processing City #147 macusani
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=america+dourada
# Processing City #148 america dourada
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=westport
# Processing City #149 westport
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=pangnirtung
# Processing City #150 pangnirtung
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tasiilaq
# Processing City #151 tasiilaq
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kaitangata
# Processing City #152 kaitangata
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=pacific+grove
# Processing City #153 pacific grove
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mitu
# Processing City #154 mitu
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=yar-sale
# Processing City #155 yar-sale
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=pangody
# Processing City #156 pangody
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=lompoc
# Processing City #157 lompoc
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sarh
# Processing City #158 sarh
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bombay
# Processing City #159 bombay
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=jalu
# Processing City #160 jalu
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=los+llanos+de+aridane
# Processing City #161 los llanos de aridane
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=husavik
# Processing City #162 husavik
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sabang
# Processing City #163 sabang
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=northam
# Processing City #164 northam
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=alofi
# Processing City #165 alofi
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=meyungs
# Processing City #166 meyungs
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=moree
# Processing City #167 moree
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=port+hardy
# Processing City #168 port hardy
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=vaitupu
# Processing City #169 vaitupu
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=esperance
# Processing City #170 esperance
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=flinders
# Processing City #171 flinders
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=dingli
# Processing City #172 dingli
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=saint+anthony
# Processing City #173 saint anthony
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=slave+lake
# Processing City #174 slave lake
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ugoofaaru
# Processing City #175 ugoofaaru
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=urbano+santos
# Processing City #176 urbano santos
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=qaanaaq
# Processing City #177 qaanaaq
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=svetlaya
# Processing City #178 svetlaya
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mar+del+plata
# Processing City #179 mar del plata
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=cherskiy
# Processing City #180 cherskiy
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=xuddur
# Processing City #181 xuddur
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=nador
# Processing City #182 nador
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=arman
# Processing City #183 arman
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=fort+nelson
# Processing City #184 fort nelson
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=abu+kamal
# Processing City #185 abu kamal
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=dalbandin
# Processing City #186 dalbandin
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tromso
# Processing City #187 tromso
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=belaya+gora
# Processing City #188 belaya gora
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=neiafu
# Processing City #189 neiafu
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=drumheller
# Processing City #190 drumheller
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=provideniya
# Processing City #191 provideniya
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tuatapere
# Processing City #192 tuatapere
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mancio+lima
# Processing City #193 mancio lima
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tulsipur
# Processing City #194 tulsipur
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sumbawa
# Processing City #195 sumbawa
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=grand+river+south+east
# Processing City #196 grand river south east
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mercedes
# Processing City #197 mercedes
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=macaboboni
# Processing City #198 macaboboni
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bagdarin
# Processing City #199 bagdarin
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=solnechnyy
# Processing City #200 solnechnyy
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ulladulla
# Processing City #201 ulladulla
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=khovu-aksy
# Processing City #202 khovu-aksy
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tanshui
# Processing City #203 tanshui
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tula
# Processing City #204 tula
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=poum
# Processing City #205 poum
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=butaritari
# Processing City #206 butaritari
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mana
# Processing City #207 mana
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=palmer
# Processing City #208 palmer
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=saleaula
# Processing City #209 saleaula
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=acapulco
# Processing City #210 acapulco
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=morros
# Processing City #211 morros
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=wahran
# Processing City #212 wahran
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=talnakh
# Processing City #213 talnakh
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=nantucket
# Processing City #214 nantucket
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mitzic
# Processing City #215 mitzic
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tabory
# Processing City #216 tabory
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=hovd
# Processing City #217 hovd
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bambous+virieux
# Processing City #218 bambous virieux
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=pasighat
# Processing City #219 pasighat
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tyler
# Processing City #220 tyler
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=the+valley
# Processing City #221 the valley
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=scottsbluff
# Processing City #222 scottsbluff
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=dingle
# Processing City #223 dingle
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ye
# Processing City #224 ye
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kulhudhuffushi
# Processing City #225 kulhudhuffushi
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=pochutla
# Processing City #226 pochutla
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=inirida
# Processing City #227 inirida
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=olinda
# Processing City #228 olinda
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=panaba
# Processing City #229 panaba
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tarudant
# Processing City #230 tarudant
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=general+roca
# Processing City #231 general roca
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=thinadhoo
# Processing City #232 thinadhoo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sao+filipe
# Processing City #233 sao filipe
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=touros
# Processing City #234 touros
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=selma
# Processing City #235 selma
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=gangotri
# Processing City #236 gangotri
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=blagoyevo
# Processing City #237 blagoyevo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sentyabrskiy
# Processing City #238 sentyabrskiy
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=hamilton
# Processing City #239 hamilton
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=faya
# Processing City #240 faya
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=khonuu
# Processing City #241 khonuu
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=pamekasan
# Processing City #242 pamekasan
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=portland
# Processing City #243 portland
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=dimapur
# Processing City #244 dimapur
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bucerias
# Processing City #245 bucerias
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bianzhuang
# Processing City #246 bianzhuang
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kodiak
# Processing City #247 kodiak
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=cidreira
# Processing City #248 cidreira
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=turukhansk
# Processing City #249 turukhansk
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tilichiki
# Processing City #250 tilichiki
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=cururupu
# Processing City #251 cururupu
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=nouadhibou
# Processing City #252 nouadhibou
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kloulklubed
# Processing City #253 kloulklubed
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=dunedin
# Processing City #254 dunedin
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kargasok
# Processing City #255 kargasok
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tuktoyaktuk
# Processing City #256 tuktoyaktuk
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tselinnoye
# Processing City #257 tselinnoye
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=chacabuco
# Processing City #258 chacabuco
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kieta
# Processing City #259 kieta
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=palabuhanratu
# Processing City #260 palabuhanratu
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tiznit
# Processing City #261 tiznit
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=chervona+sloboda
# Processing City #262 chervona sloboda
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=hailar
# Processing City #263 hailar
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=chimbote
# Processing City #264 chimbote
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kruisfontein
# Processing City #265 kruisfontein
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=corn+island
# Processing City #266 corn island
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=lagoa
# Processing City #267 lagoa
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ponta+delgada
# Processing City #268 ponta delgada
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sumoto
# Processing City #269 sumoto
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=pucallpa
# Processing City #270 pucallpa
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=zastavna
# Processing City #271 zastavna
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=nara
# Processing City #272 nara
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=san-pedro
# Processing City #273 san-pedro
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=butler
# Processing City #274 butler
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mahebourg
# Processing City #275 mahebourg
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=jumla
# Processing City #276 jumla
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=klaksvik
# Processing City #277 klaksvik
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=narsaq
# Processing City #278 narsaq
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tateyama
# Processing City #279 tateyama
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sur
# Processing City #280 sur
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ponta+do+sol
# Processing City #281 ponta do sol
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=roald
# Processing City #282 roald
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sola
# Processing City #283 sola
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=taoudenni
# Processing City #284 taoudenni
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=san+policarpo
# Processing City #285 san policarpo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=hualmay
# Processing City #286 hualmay
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=spantov
# Processing City #287 spantov
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=pointe-noire
# Processing City #288 pointe-noire
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bolungarvik
# Processing City #289 bolungarvik
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kahului
# Processing City #290 kahului
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bontang
# Processing City #291 bontang
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=nabire
# Processing City #292 nabire
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bavleny
# Processing City #293 bavleny
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=jiangyou
# Processing City #294 jiangyou
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=brae
# Processing City #295 brae
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=neryungri
# Processing City #296 neryungri
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ishigaki
# Processing City #297 ishigaki
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=lazarev
# Processing City #298 lazarev
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=partizanskoye
# Processing City #299 partizanskoye
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=uribia
# Processing City #300 uribia
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=jamestown
# Processing City #301 jamestown
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=trofors
# Processing City #302 trofors
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=katobu
# Processing City #303 katobu
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kununurra
# Processing City #304 kununurra
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=chon+daen
# Processing City #305 chon daen
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=vao
# Processing City #306 vao
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=corinth
# Processing City #307 corinth
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=constitucion
# Processing City #308 constitucion
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kendari
# Processing City #309 kendari
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mataram
# Processing City #310 mataram
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=burica
# Processing City #311 burica
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=hervey+bay
# Processing City #312 hervey bay
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=lavrentiya
# Processing City #313 lavrentiya
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=paracuru
# Processing City #314 paracuru
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kodinsk
# Processing City #315 kodinsk
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=santa+cruz+de+tenerife
# Processing City #316 santa cruz de tenerife
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=breves
# Processing City #317 breves
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kathmandu
# Processing City #318 kathmandu
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=aliquippa
# Processing City #319 aliquippa
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=hithadhoo
# Processing City #320 hithadhoo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=maua
# Processing City #321 maua
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=teguise
# Processing City #322 teguise
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tuy+hoa
# Processing City #323 tuy hoa
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=san+antonio
# Processing City #324 san antonio
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=papasquiaro
# Processing City #325 papasquiaro
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=caravelas
# Processing City #326 caravelas
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=makakilo+city
# Processing City #327 makakilo city
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=karaul
# Processing City #328 karaul
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=hasaki
# Processing City #329 hasaki
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=salinopolis
# Processing City #330 salinopolis
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=fomboni
# Processing City #331 fomboni
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=clyde+river
# Processing City #332 clyde river
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=baherden
# Processing City #333 baherden
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ilhabela
# Processing City #334 ilhabela
# ------------
# ...
# Processing City #502 champua
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ballina
# Processing City #503 ballina
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=nishihara
# Processing City #504 nishihara
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=san+miguel
# Processing City #505 san miguel
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kawalu
# Processing City #506 kawalu
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=fairlie
# Processing City #507 fairlie
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=koungheul
# Processing City #508 koungheul
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=okhotsk
# Processing City #509 okhotsk
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=katangi
# Processing City #510 katangi
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kholm
# Processing City #511 kholm
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=dyatkovo
# Processing City #512 dyatkovo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=anadyr
# Processing City #513 anadyr
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=talaya
# Processing City #514 talaya
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sesimbra
# Processing City #515 sesimbra
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=oros
# Processing City #516 oros
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=verkhoyansk
# Processing City #517 verkhoyansk
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=katangli
# Processing City #518 katangli
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=san+juan
# Processing City #519 san juan
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kjollefjord
# Processing City #520 kjollefjord
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=road+town
# Processing City #521 road town
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mishan
# Processing City #522 mishan
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=laguna
# Processing City #523 laguna
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=lanxi
# Processing City #524 lanxi
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sarlat-la-caneda
# Processing City #525 sarlat-la-caneda
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=carutapera
# Processing City #526 carutapera
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=cockburn+town
# Processing City #527 cockburn town
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=harper
# Processing City #528 harper
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sanary-sur-mer
# Processing City #529 sanary-sur-mer
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tiksi
# Processing City #530 tiksi
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=fazilka
# Processing City #531 fazilka
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=wajima
# Processing City #532 wajima
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=lewisporte
# Processing City #533 lewisporte
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=dhidhdhoo
# Processing City #534 dhidhdhoo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=zhigalovo
# Processing City #535 zhigalovo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=gambela
# Processing City #536 gambela
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=lorengau
# Processing City #537 lorengau
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=draguseni
# Processing City #538 draguseni
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=betim
# Processing City #539 betim
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=araioses
# Processing City #540 araioses
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bengkulu
# Processing City #541 bengkulu
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bubaque
# Processing City #542 bubaque
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=muros
# Processing City #543 muros
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=riyadh
# Processing City #544 riyadh
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ambodifototra
# Processing City #545 ambodifototra
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=dwarka
# Processing City #546 dwarka
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=halalo
# Processing City #547 halalo
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=myitkyina
# Processing City #548 myitkyina
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=rosetta
# Processing City #549 rosetta
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=camacha
# Processing City #550 camacha
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=magugu
# Processing City #551 magugu
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ustyuzhna
# Processing City #552 ustyuzhna
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=itaituba
# Processing City #553 itaituba
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=manadhoo
# Processing City #554 manadhoo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=malacky
# Processing City #555 malacky
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=divnogorsk
# Processing City #556 divnogorsk
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sembe
# Processing City #557 sembe
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=skalistyy
# Processing City #558 skalistyy
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=semenivka
# Processing City #559 semenivka
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=mugumu
# Processing City #560 mugumu
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tura
# Processing City #561 tura
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=hambantota
# Processing City #562 hambantota
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=roebourne
# Processing City #563 roebourne
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=champerico
# Processing City #564 champerico
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=diffa
# Processing City #565 diffa
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=druzhba
# Processing City #566 druzhba
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=zmiyiv
# Processing City #567 zmiyiv
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=gawler
# Processing City #568 gawler
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=maniitsoq
# Processing City #569 maniitsoq
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kumo
# Processing City #570 kumo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=sataua
# Processing City #571 sataua
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=hay+river
# Processing City #572 hay river
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=conde
# Processing City #573 conde
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=saint-francois
# Processing City #574 saint-francois
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ruatoria
# Processing City #575 ruatoria
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=den+helder
# Processing City #576 den helder
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=krivopolyanye
# Processing City #577 krivopolyanye
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=yirol
# Processing City #578 yirol
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=pindi+gheb
# Processing City #579 pindi gheb
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=buraydah
# Processing City #580 buraydah
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tagab
# Processing City #581 tagab
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=port-gentil
# Processing City #582 port-gentil
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=whitehorse
# Processing City #583 whitehorse
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=cordeiro
# Processing City #584 cordeiro
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=huarmey
# Processing City #585 huarmey
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=geraldton
# Processing City #586 geraldton
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=majene
# Processing City #587 majene
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=aktash
# Processing City #588 aktash
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=lolua
# Processing City #589 lolua
# Missing field/result... skipping.
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=monteagudo
# Processing City #590 monteagudo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=ancud
# Processing City #591 ancud
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=vila+velha
# Processing City #592 vila velha
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=inongo
# Processing City #593 inongo
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=miraflores
# Processing City #594 miraflores
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=enshi
# Processing City #595 enshi
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=proletarsk
# Processing City #596 proletarsk
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=tsiroanomandidy
# Processing City #597 tsiroanomandidy
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=erenhot
# Processing City #598 erenhot
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=shimoda
# Processing City #599 shimoda
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=bongor
# Processing City #600 bongor
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=novoagansk
# Processing City #601 novoagansk
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=jiwani
# Processing City #602 jiwani
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=urumqi
# Processing City #603 urumqi
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=show+low
# Processing City #604 show low
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=kenai
# Processing City #605 kenai
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=poso
# Processing City #606 poso
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=wisconsin+rapids
# Processing City #607 wisconsin rapids
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=manono
# Processing City #608 manono
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=marsa+matruh
# Processing City #609 marsa matruh
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=haines+junction
# Processing City #610 haines junction
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=little+rock
# Processing City #611 little rock
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=marzuq
# Processing City #612 marzuq
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=gorom-gorom
# Processing City #613 gorom-gorom
# ------------
# http://api.openweathermap.org/data/2.5/weather?appid=34d602b56b9384c61812f09cfb7c21bc&q=spencer
# Processing City #614 spencer
# ------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Take the list of dictionaries all_data and create a dataframe.
all_data = pd.DataFrame(all_data)

# %%
# Display df
all_data
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          Ilulissat          93      GL  1584329447        47  69.22  -51.10
# 1            Ushuaia          40      AR  1584329445        71 -54.80  -68.30
# 2            Rikitea           3      PF  1584329417        79 -23.12 -134.97
# 3             Jasper          90      US  1584329424        81  37.20  -94.35
# 4           Saldanha          99      ZA  1584329475        63 -33.01   17.94
# ..               ...         ...     ...         ...       ...    ...     ...
# 565  Haines Junction           7      CA  1584329602        92  60.75 -137.51
# 566      Little Rock          90      US  1584329603        81  34.75  -92.29
# 567           Marzuq         100      YE  1584329603        66  14.40   46.47
# 568      Gorom-Gorom          93      BF  1584329603        13  14.44   -0.24
# 569          Spencer          90      US  1584329418        81  43.14  -95.14
#
#      Max Temp  Wind Speed
# 0      250.15        3.60
# 1      285.15        1.96
# 2      299.61        5.68
# 3      279.15        1.50
# 4      291.15        3.10
# ..        ...         ...
# 565    265.25        0.34
# 566    280.37        6.20
# 567    292.15        1.00
# 568    298.89        4.78
# 569    273.71        2.60
#
# [570 rows x 9 columns]

# %%
# Kelvin to F: T(°F) = T(K) × 9/5 - 459.67
all_data['Max Temp'] = (((all_data['Max Temp'] * 9) / 5) - 459.67).round(2)
all_data
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          Ilulissat          93      GL  1584329447        47  69.22  -51.10
# 1            Ushuaia          40      AR  1584329445        71 -54.80  -68.30
# 2            Rikitea           3      PF  1584329417        79 -23.12 -134.97
# 3             Jasper          90      US  1584329424        81  37.20  -94.35
# 4           Saldanha          99      ZA  1584329475        63 -33.01   17.94
# ..               ...         ...     ...         ...       ...    ...     ...
# 565  Haines Junction           7      CA  1584329602        92  60.75 -137.51
# 566      Little Rock          90      US  1584329603        81  34.75  -92.29
# 567           Marzuq         100      YE  1584329603        66  14.40   46.47
# 568      Gorom-Gorom          93      BF  1584329603        13  14.44   -0.24
# 569          Spencer          90      US  1584329418        81  43.14  -95.14
#
#      Max Temp  Wind Speed
# 0       -9.40        3.60
# 1       53.60        1.96
# 2       79.63        5.68
# 3       42.80        1.50
# 4       64.40        3.10
# ..        ...         ...
# 565     17.78        0.34
# 566     45.00        6.20
# 567     66.20        1.00
# 568     78.33        4.78
# 569     33.01        2.60
#
# [570 rows x 9 columns]

# %%
# Save CSV file of API called df
all_data.to_csv('random_cities.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
values_lat = all_data['Lat']
values_temp = all_data['Max Temp']



plt.scatter(values_lat,values_temp)
plt.title("Temperature Around Equator")
plt.xlabel("Latitudes")
plt.ylabel("Max Temp")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f0fe7f98e7f5> in <module>
# ----> 1 values_lat = all_data['Lat']
#       2 values_temp = all_data['Max Temp']
#       3
#       4
#       5
#
# NameError: name 'all_data' is not defined

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
values_lat = all_data['Lat']
values_hum = all_data['Humidity']



plt.scatter(values_lat,values_hum)
plt.title("Temperature Around Equator")
plt.xlabel("Latitudes")
plt.ylabel("Humidity")
# Out:
# Text(0, 0.5, 'Humidity')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
values_lat = all_data['Lat']
values_cloud = all_data['Cloudiness']



plt.scatter(values_lat,values_cloud)
plt.title("Latitude vs. Cloudiness")
plt.xlabel("Latitudes")
plt.ylabel("Cloudiness")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d62e7e18fc1d> in <module>
# ----> 1 values_lat = all_data['Lat']
#       2 values_cloud = all_data['Cloudiness']
#       3
#       4
#       5
#
# NameError: name 'all_data' is not defined

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
values_lat = all_data['Lat']
values_wind = all_data['Wind Speed']



plt.scatter(values_lat,values_wind)
plt.title("Latitude vs. Wind Speed Plo")
plt.xlabel("Latitudes")
plt.ylabel("Wind")
# Out:
# Text(0, 0.5, 'Wind')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_regression(x_values, y_values, title, x_lab, y_lab):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(6,10),fontsize=15,color="red")
    plt.title(title)
    plt.xlabel(x_lab)
    plt.ylabel(y_lab)
    plt.show()
    
linear_regression(values_lat, values_wind, 'Title', 'Latitude', 'Wind Speed')

# %%
# Filter to Northern Hemisphere
df_northern = all_data.loc[all_data['Lat'] > 0]
df_northern
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          Ilulissat          93      GL  1584329447        47  69.22  -51.10
# 3             Jasper          90      US  1584329424        81  37.20  -94.35
# 5          Upernavik           0      GL  1584329476        78  72.79  -56.15
# 8             Loreto         100      MX  1584329476        58  22.27 -101.97
# 9       Saint George           1      US  1584329476        66  37.10 -113.58
# ..               ...         ...     ...         ...       ...    ...     ...
# 565  Haines Junction           7      CA  1584329602        92  60.75 -137.51
# 566      Little Rock          90      US  1584329603        81  34.75  -92.29
# 567           Marzuq         100      YE  1584329603        66  14.40   46.47
# 568      Gorom-Gorom          93      BF  1584329603        13  14.44   -0.24
# 569          Spencer          90      US  1584329418        81  43.14  -95.14
#
#      Max Temp  Wind Speed
# 0       -9.40        3.60
# 3       42.80        1.50
# 5      -22.16        2.75
# 8       64.54        8.07
# 9       55.99        4.10
# ..        ...         ...
# 565     17.78        0.34
# 566     45.00        6.20
# 567     66.20        1.00
# 568     78.33        4.78
# 569     33.01        2.60
#
# [400 rows x 9 columns]

# %%
# Filter to Southern Hemisphere
df_southern = all_data.loc[all_data['Lat'] < 0]
df_southern
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 1            Ushuaia          40      AR  1584329445        71 -54.80  -68.30
# 2            Rikitea           3      PF  1584329417        79 -23.12 -134.97
# 4           Saldanha          99      ZA  1584329475        63 -33.01   17.94
# 6            Mataura          97      NZ  1584329476        68 -46.19  168.86
# 7            Ahipara         100      NZ  1584329476        74 -35.17  173.17
# ..               ...         ...     ...         ...       ...    ...     ...
# 547       Vila Velha          20      BR  1584329374        88 -20.33  -40.29
# 548           Inongo          80      CD  1584329599        95  -1.95   18.27
# 552  Tsiroanomandidy          41      MG  1584329600        95 -18.77   46.03
# 561             Poso          85      ID  1584329601        75  -1.40  120.75
# 563           Manono         100      CD  1584329602        95  -7.30   27.42
#
#      Max Temp  Wind Speed
# 1       53.60        1.96
# 2       79.63        5.68
# 4       64.40        3.10
# 6       53.01        6.26
# 7       66.85        5.48
# ..        ...         ...
# 547     77.00        1.50
# 548     72.01        0.63
# 552     66.74        0.31
# 561     75.78        2.13
# 563     69.89        0.48
#
# [170 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
values_north_temp = df_northern['Max Temp']
values_north_lat = df_northern['Lat']

linear_regression(values_north_lat, values_north_temp, 'Max Temp vs. Latitude', 'Latitudes', 'Max Temp')

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
values_north_hum = df_southern['Humidity']
values_north_lat = df_southern['Lat']

linear_regression(values_north_lat, values_north_hum, 'Humidity (%) vs. Latitude', 'Latitudes', 'Humidity')

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
values_north_hum = df_northern['Humidity']
values_north_lat = df_northern['Lat']

linear_regression(values_north_lat, values_north_hum, 'Humidity (%) vs. Latitude', 'Latitudes', 'Humidity')

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
values_north_hum = df_southern['Humidity']
values_north_lat = df_southern['Lat']

linear_regression(values_north_lat, values_north_hum, 'Humidity (%) vs. Latitude', 'Latitudes', 'Humidity')

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
values_north_cloud = df_northern['Cloudiness']
values_north_lat = df_northern['Lat']

linear_regression(values_north_lat, values_north_cloud, 'Cloudiness (%) vs. Latitude', 'Latitudes', 'Cloudiness')

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
values_north_cloud = df_southern['Cloudiness']
values_north_lat = df_southern['Lat']

linear_regression(values_north_lat, values_north_cloud, 'Cloudiness (%) vs. Latitude', 'Latitudes', 'Cloudiness')

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
values_north_wind = df_northern['Wind Speed']
values_north_lat = df_northern['Lat']

linear_regression(values_north_lat, values_north_wind, 'Wind Speed (mph) vs. Latitude', 'Latitudes', 'Wind Speed')

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
values_north_wind = df_southern['Wind Speed']
values_north_lat = df_southern['Lat']

linear_regression(values_north_lat, values_north_wind, 'Wind Speed (mph) vs. Latitude', 'Latitudes', 'Wind Speed')
